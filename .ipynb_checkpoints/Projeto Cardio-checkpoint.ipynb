# %% [markdown]
# # 1 IMPORTS

# %%
import pickle
import warnings
import sqlalchemy as db
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

from scipy.stats import chi2_contingency
from scipy.stats import pointbiserialr
from collections import Counter
from pyitlib import discrete_random_variable as drv
from itertools import permutations


from sklearn import metrics
from tabulate import tabulate
import scikitplot as skplt


from sklearn.preprocessing import RobustScaler, MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from boruta import BorutaPy
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
import xgboost as xgb
from catboost import CatBoostClassifier
import lightgbm as lightgbm
from lightgbm import LGBMClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score, cohen_kappa_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report, roc_curve, brier_score_loss


warnings.filterwarnings('ignore')


from statsmodels.stats.weightstats import DescrStatsW, CompareMeans

# %% [markdown]
# ## 1.1 Definição de funções

# %%
# configurações do Seaborn
sns.set_palette('tab10')
sns.set_style('darkgrid')

# média das datas 
def data_mean(x):
    if x['Altura'] < 1:
        mean = data['Altura'].loc[(data['Altura'] >= 1) & (data['Altura'] <= 2.1)].mean()
        return round(mean,2)
    elif x['Altura'] > 2.1:
        mean = data['Altura'].loc[(data['Altura'] >= 1) & (data['Altura'] <= 2.1)].mean()
        return round(mean,2)
    else:
        return x['Altura']

# Padrão para plotagens    
def data_load(ax1, title, xlabel, ylabel):
    ax1.set_title(title, fontdict={'fontsize': 18})
    ax1.set_xlabel(xlabel, fontdict={'fontsize': 15})
    ax1.set_ylabel(ylabel, fontdict={'fontsize': 15})
    return None


# Classe para correlação e métricas
class Utilities(object):
    def cramerv(self, var_x, var_y):
        # matriz da confusão
        confusion_matrix_v = pd.crosstab(var_x, var_y).values

        # soma de todos os valores da matriz
        n = confusion_matrix_v.sum()

        # linha e coluna
        l, c = confusion_matrix_v.shape

        # qui-quadrado
        chi2 = chi2_contingency(confusion_matrix_v)[0]

        # correção 
        chi2corr = max(0, chi2 - (c-1) * (l-1) / (n-1))
        ccorr = c - (c-1) ** 2 / (n-1)
        lcorr = l - (l-1) ** 2 / (n-1)

        # retornar ao crame v
        return np.sqrt((chi2corr/n) / min(ccorr-1, lcorr-1))

    # performance de modelos de classificação 
    def performance_modelo(self, X_train, X_test, y_train, y_test, threshold, classifiers):

        dataframe_performance = pd.DataFrame()

        for clf in classifiers:
            print("Training " + type(clf).__name__ + "...")
            
            clf.fit(X_train, y_train)

            clf_probs = clf.predict_proba(X_test)

            clf_accuracy, clf_kappa, clf_f1, clf_auc, clf_precision, clf_recall = self.calculo_metricas_modelos(clf,
                                                                                                               X_test, y_test,
                                                                                                               clf_probs, threshold)

            clf_dict = {
                'model': [type(clf).__name__, '---'],
                'precision': [clf_precision, np.nan],
                'recall': [clf_recall, np.nan],
                'f1-Score': [clf_f1, np.nan],
                'ROC AUC': [clf_auc, np.nan],
                'accuracy': [clf_accuracy, np.nan],
                'cohen kappa': [clf_kappa, np.nan]}

            dataframe_performance = pd.concat([dataframe_performance, pd.DataFrame(clf_dict)])

        dataframe_performance = dataframe_performance.reset_index()

        dataframe_performance.drop('index', axis=1, inplace=True)

        rows_to_drop = np.arange(1, len(classifiers)*2, 2)

        dataframe_performance.drop(rows_to_drop, inplace=True)

        return dataframe_performance

    def calculo_metricas_modelos(self, model, X_test, y_test, model_probs, threshold):
        """
            Calcular Acurácia, F1-Score, PR AUC
        """
        probs = pd.DataFrame(model_probs[:, 1], columns=['prob'])

        y_pred = probs['prob'].apply(lambda x: 1 if x > threshold else 0)

        f1 = f1_score(y_test, y_pred)

        accuracy = accuracy_score(y_test, y_pred)

        kappa = cohen_kappa_score(y_test, y_pred)

        auc_score = roc_auc_score(y_test, probs)

        precision = precision_score(y_test, y_pred)

        recall = recall_score(y_test, y_pred)

        return accuracy, kappa, f1, auc_score, precision, recall

# %%
# Classe de utilidades
UG = Utilities()

# %% [markdown]
# ## 1.2 Carregando Dados

# %%
# Carregando dataset
data = pd.read_csv('dataset/cardio_train.csv', sep=';')

# %% [markdown]
# # 2 Descrição dos dados

# %% [markdown]
# ## 2.1 Observação dos dados

# %%
# Checando dataset
data.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ## 2.2 Formatação e tipos dos dados

# %%
# Checando colunas
data.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
# Traduzindo colunas
data.columns = ['id', 'Idade', 'Gênero', 'Altura', 'Peso', 'Pressão arterial sistólica', 'Pressão sanguínea diastólica',
       'Colesterol', 'Glicose', 'Fuma', 'Álcool', 'Atividade física', 'Presença ou ausência de doença cardiovascular']
data
# Out:
#           id  Idade  Gênero  Altura   Peso  Pressão arterial sistólica  \
# 0          0  18393       2     168   62.0                         110
# 1          1  20228       1     156   85.0                         140
# 2          2  18857       1     165   64.0                         130
# 3          3  17623       2     169   82.0                         150
# 4          4  17474       1     156   56.0                         100
# ...      ...    ...     ...     ...    ...                         ...
# 69995  99993  19240       2     168   76.0                         120
# 69996  99995  22601       1     158  126.0                         140
# 69997  99996  19066       2     183  105.0                         180
# 69998  99998  22431       1     163   72.0                         135
# 69999  99999  20540       1     170   72.0                         120
#
#        Pressão sanguínea diastólica  Colesterol  Glicose  Fuma  Álcool  \
# 0                                80           1        1     0       0
# 1                                90           3        1     0       0
# 2                                70           3        1     0       0
# 3                               100           1        1     0       0
# 4                                60           1        1     0       0
# ...                             ...         ...      ...   ...     ...
# 69995                            80           1        1     1       0
# 69996                            90           2        2     0       0
# 69997                            90           3        1     0       1
# 69998                            80           1        2     0       0
# 69999                            80           2        1     0       0
#
#        Atividade física  Presença ou ausência de doença cardiovascular
# 0                     1                                              0
# 1                     1                                              1
# 2                     0                                              1
# 3                     1                                              1
# 4                     0                                              0
# ...                 ...                                            ...
# 69995                 1                                              0
# 69996                 1                                              1
# 69997                 0                                              1
# 69998                 0                                              1
# 69999                 1                                              0
#
# [70000 rows x 13 columns]

# %% [markdown]
# Vamos colocar a ferramenta **altura** em metros para facilitar a visualização e criar uma ferramenta de **idade** nova chamada **Idade_2** para não perder informação futuramente na coluna atual que está em quantidade de dias.

# %%
# Reescalando Altura e Idade 
data['Altura'] = round(data['Altura']/100,2)
data['Idade_2'] = round(data['Idade']/365, 1)  
data
# Out:
#           id  Idade  Gênero  Altura   Peso  Pressão arterial sistólica  \
# 0          0  18393       2    1.68   62.0                         110
# 1          1  20228       1    1.56   85.0                         140
# 2          2  18857       1    1.65   64.0                         130
# 3          3  17623       2    1.69   82.0                         150
# 4          4  17474       1    1.56   56.0                         100
# ...      ...    ...     ...     ...    ...                         ...
# 69995  99993  19240       2    1.68   76.0                         120
# 69996  99995  22601       1    1.58  126.0                         140
# 69997  99996  19066       2    1.83  105.0                         180
# 69998  99998  22431       1    1.63   72.0                         135
# 69999  99999  20540       1    1.70   72.0                         120
#
#        Pressão sanguínea diastólica  Colesterol  Glicose  Fuma  Álcool  \
# 0                                80           1        1     0       0
# 1                                90           3        1     0       0
# 2                                70           3        1     0       0
# 3                               100           1        1     0       0
# 4                                60           1        1     0       0
# ...                             ...         ...      ...   ...     ...
# 69995                            80           1        1     1       0
# 69996                            90           2        2     0       0
# 69997                            90           3        1     0       1
# 69998                            80           1        2     0       0
# 69999                            80           2        1     0       0
#
#        Atividade física  Presença ou ausência de doença cardiovascular  \
# 0                     1                                              0
# 1                     1                                              1
# 2                     0                                              1
# 3                     1                                              1
# 4                     0                                              0
# ...                 ...                                            ...
# 69995                 1                                              0
# 69996                 1                                              1
# 69997                 0                                              1
# 69998                 0                                              1
# 69999                 1                                              0
#
#        Idade_2
# 0         50.4
# 1         55.4
# 2         51.7
# 3         48.3
# 4         47.9
# ...        ...
# 69995     52.7
# 69996     61.9
# 69997     52.2
# 69998     61.5
# 69999     56.3
#
# [70000 rows x 14 columns]

# %%
# Checando dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   id                                             70000 non-null  int64
#  1   Idade                                          70000 non-null  int64
#  2   Gênero                                         70000 non-null  int64
#  3   Altura                                         70000 non-null  float64
#  4   Peso                                           70000 non-null  float64
#  5   Pressão arterial sistólica                     70000 non-null  int64
#  6   Pressão sanguínea diastólica                   70000 non-null  int64
#  7   Colesterol                                     70000 non-null  int64
#  8   Glicose                                        70000 non-null  int64
#  9   Fuma                                           70000 non-null  int64
#  10  Álcool                                         70000 non-null  int64
#  11  Atividade física                               70000 non-null  int64
#  12  Presença ou ausência de doença cardiovascular  70000 non-null  int64
#  13  Idade_2                                        70000 non-null  float64
# dtypes: float64(3), int64(11)
# memory usage: 7.5 MB

# %% [markdown]
# ## 2.3 Checando e Tratando os dados vazios

# %%
# Checando dados vazios
data.isna().sum()
# Out:
# id                                               0
# Idade                                            0
# Gênero                                           0
# Altura                                           0
# Peso                                             0
# Pressão arterial sistólica                       0
# Pressão sanguínea diastólica                     0
# Colesterol                                       0
# Glicose                                          0
# Fuma                                             0
# Álcool                                           0
# Atividade física                                 0
# Presença ou ausência de doença cardiovascular    0
# Idade_2                                          0
# dtype: int64

# %% [markdown]
# ## 3 Estatística descritiva

# %% [markdown]
# ### 3.1 Atributos Numéricos
# **1**. Vamos criar 2 ferramentas para visualizar melhor as estatísticas de curtose e simetria.
#
# **2**. Percebemos um valor muito alto na curtose de Pressão arterial sistólica e Pressão sanguínea diastólica devido a presença de outliers.
#
# **3**. Nas ferramentas altura e Peso existem alguns outliers nos valores mínimos e máximos.

# %%
# Selecionando dados int e float
NA = data.select_dtypes(['int64', 'float64'])

# %%
# Criando recurso de simetria 
Simetria = pd.DataFrame(NA.apply(lambda x: x.skew())).round(2).T
Simetria.rename(index={0: 'Simetria'}, inplace=True)

# Criando recurso de curtose
Curtose = pd.DataFrame(NA.apply(lambda x: x.kurtosis())).round(2).T
Curtose.rename(index={0: 'Curtose'}, inplace=True)

describe = NA.describe().round(2)
m = pd.concat([describe, Simetria, Curtose], axis=0)
m.iloc[:,1:]
# Out:
#              Idade    Gênero    Altura      Peso  Pressão arterial sistólica  \
# count     70000.00  70000.00  70000.00  70000.00                    70000.00
# mean      19468.87      1.35      1.64     74.21                      128.82
# std        2467.25      0.48      0.08     14.40                      154.01
# min       10798.00      1.00      0.55     10.00                     -150.00
# 25%       17664.00      1.00      1.59     65.00                      120.00
# 50%       19703.00      1.00      1.65     72.00                      120.00
# 75%       21327.00      2.00      1.70     82.00                      140.00
# max       23713.00      2.00      2.50    200.00                    16020.00
# Simetria     -0.31      0.63     -0.64      1.01                       85.30
# Curtose      -0.82     -1.60      7.94      2.59                     7580.07
#
#           Pressão sanguínea diastólica  Colesterol   Glicose      Fuma  \
# count                         70000.00    70000.00  70000.00  70000.00
# mean                             96.63        1.37      1.23      0.09
# std                             188.47        0.68      0.57      0.28
# min                             -70.00        1.00      1.00      0.00
# 25%                              80.00        1.00      1.00      0.00
# 50%                              80.00        1.00      1.00      0.00
# 75%                              90.00        2.00      1.00      0.00
# max                           11000.00        3.00      3.00      1.00
# Simetria                         32.11        1.59      2.40      2.91
# Curtose                        1425.91        0.99      4.29      6.44
#
#             Álcool  Atividade física  \
# count     70000.00          70000.00
# mean          0.05              0.80
# std           0.23              0.40
# min           0.00              0.00
# 25%           0.00              1.00
# 50%           0.00              1.00
# 75%           0.00              1.00
# max           1.00              1.00
# Simetria      3.96             -1.53
# Curtose      13.66              0.34
#
#           Presença ou ausência de doença cardiovascular   Idade_2
# count                                           70000.0  70000.00
# mean                                                0.5     53.34
# std                                                 0.5      6.76
# min                                                 0.0     29.60
# 25%                                                 0.0     48.40
# 50%                                                 0.0     54.00
# 75%                                                 1.0     58.40
# max                                                 1.0     65.00
# Simetria                                            0.0     -0.31
# Curtose                                            -2.0     -0.82

# %%
# Criando classe de curtose
Classe_curtose = pd.DataFrame(m.loc["Curtose"].apply(lambda x:
                  'leptocúrtica_pos' if (x > 0)
                   else ' mesocúrtica' if (x == 0)
                   else 'platicúrtica_neg')).T
Classe_curtose.rename(index={'Curtose': 'Classe curtose'}, inplace=True)

#Criando classe de simetria
Classe_simetria = pd.DataFrame(m.loc["Simetria"].apply(lambda x:
                  'quase simétrica' if (((x > 0) & (x < 0.5)) | ((x < 0) & (x > -0.5))) 
                   else 'médio enviesado' if (((x > 0.5) & (x < 1.0)) | ((x < -0.5) & (x > -1.0))) 
                   else 'muito enviesado')).T
Classe_simetria.rename(index={'Simetria': 'Classe_simetria'}, inplace=True)

m = pd.concat([m, Classe_curtose, Classe_simetria], axis=0)
m.iloc[:,1:]
# Out:
#                             Idade            Gênero            Altura  \
# count                     70000.0           70000.0           70000.0
# mean                     19468.87              1.35              1.64
# std                       2467.25              0.48              0.08
# min                       10798.0               1.0              0.55
# 25%                       17664.0               1.0              1.59
# 50%                       19703.0               1.0              1.65
# 75%                       21327.0               2.0               1.7
# max                       23713.0               2.0               2.5
# Simetria                    -0.31              0.63             -0.64
# Curtose                     -0.82              -1.6              7.94
# Classe curtose   platicúrtica_neg  platicúrtica_neg  leptocúrtica_pos
# Classe_simetria   quase simétrica   médio enviesado   médio enviesado
#
#                              Peso Pressão arterial sistólica  \
# count                     70000.0                    70000.0
# mean                        74.21                     128.82
# std                          14.4                     154.01
# min                          10.0                     -150.0
# 25%                          65.0                      120.0
# 50%                          72.0                      120.0
# 75%                          82.0                      140.0
# max                         200.0                    16020.0
# Simetria                     1.01                       85.3
# Curtose                      2.59                    7580.07
# Classe curtose   leptocúrtica_pos           leptocúrtica_pos
# Classe_simetria   muito enviesado            muito enviesado
#
#                 Pressão sanguínea diastólica        Colesterol  \
# count                                70000.0           70000.0
# mean                                   96.63              1.37
# std                                   188.47              0.68
# min                                    -70.0               1.0
# 25%                                     80.0               1.0
# 50%                                     80.0               1.0
# 75%                                     90.0               2.0
# max                                  11000.0               3.0
# Simetria                               32.11              1.59
# Curtose                              1425.91              0.99
# Classe curtose              leptocúrtica_pos  leptocúrtica_pos
# Classe_simetria              muito enviesado   muito enviesado
#
#                           Glicose              Fuma            Álcool  \
# count                     70000.0           70000.0           70000.0
# mean                         1.23              0.09              0.05
# std                          0.57              0.28              0.23
# min                           1.0               0.0               0.0
# 25%                           1.0               0.0               0.0
# 50%                           1.0               0.0               0.0
# 75%                           1.0               0.0               0.0
# max                           3.0               1.0               1.0
# Simetria                      2.4              2.91              3.96
# Curtose                      4.29              6.44             13.66
# Classe curtose   leptocúrtica_pos  leptocúrtica_pos  leptocúrtica_pos
# Classe_simetria   muito enviesado   muito enviesado   muito enviesado
#
#                  Atividade física  \
# count                     70000.0
# mean                          0.8
# std                           0.4
# min                           0.0
# 25%                           1.0
# 50%                           1.0
# 75%                           1.0
# max                           1.0
# Simetria                    -1.53
# Curtose                      0.34
# Classe curtose   leptocúrtica_pos
# Classe_simetria   muito enviesado
#
#                 Presença ou ausência de doença cardiovascular  \
# count                                                 70000.0
# mean                                                      0.5
# std                                                       0.5
# min                                                       0.0
# 25%                                                       0.0
# 50%                                                       0.0
# 75%                                                       1.0
# max                                                       1.0
# Simetria                                                  0.0
# Curtose                                                  -2.0
# Classe curtose                               platicúrtica_neg
# Classe_simetria                               muito enviesado
#
#                           Idade_2
# count                     70000.0
# mean                        53.34
# std                          6.76
# min                          29.6
# 25%                          48.4
# 50%                          54.0
# 75%                          58.4
# max                          65.0
# Simetria                    -0.31
# Curtose                     -0.82
# Classe curtose   platicúrtica_neg
# Classe_simetria   quase simétrica

# %% [markdown]
# ### 3.2 Atributos Categóricos

# %%
# Selecionando dados object
CA = data.select_dtypes(['object'])

# %%
CA.apply( lambda x: x.unique().shape[0] )
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # 4 Filtrando o quadro de dados

# %% [markdown]
# Removeremos os outliers através da implementação da média nas **alturas** selecionadas abaixo devido à quantidade ser baixa e os outros como o **Peso**, **Pressão sanguínea diastólica** e **Pressão sanguínea sistólica** vamos remover.

# %% [markdown]
# ## 4.1 Removendo valores discrepantes

# %%
# Removendo outlierss
data_no_outliers = data.copy()
data_no_outliers['Altura'] = data.apply(data_mean, axis=1)

data_remove = data_no_outliers.loc[(data_no_outliers['Peso'] < 40) | (data_no_outliers['Peso'] > 150)] # devido a quantidade ser alta
data_no_outliers = data_no_outliers.drop(data_remove.index)

data_remove1 = data_no_outliers.loc[(data['Pressão sanguínea diastólica'] < 60) | (data_no_outliers['Pressão sanguínea diastólica'] > 150)]
data_no_outliers = data_no_outliers.drop(data_remove1.index)

data_remove2 = data_no_outliers.loc[(data_no_outliers['Pressão arterial sistólica'] < 90) | (data_no_outliers['Pressão arterial sistólica'] > 210)]
data_no_outliers = data_no_outliers.drop(data_remove2.index)

# %% [markdown]
# ## 4.2 Checando
# Após ajustarmos os **outliers** e os **NA** que não existiam, observamos que está tudo certo agora.

# %%
# Checando outliers e valores vazios
NA = data_no_outliers.select_dtypes(['int64', 'float64'])

Simetria = pd.DataFrame(NA.apply(lambda x: x.skew())).round(2).T
Simetria.rename(index={0: 'Simetria'}, inplace=True)

Curtose = pd.DataFrame(NA.apply(lambda x: x.kurtosis())).round(2).T
Curtose.rename(index={0: 'Curtose'}, inplace=True)

describe = NA.describe().round(2)
m = pd.concat([describe, Simetria, Curtose], axis=0)
m.iloc[:,1:]
# Out:
#              Idade    Gênero    Altura      Peso  Pressão arterial sistólica  \
# count     68392.00  68392.00  68392.00  68392.00                    68392.00
# mean      19465.83      1.35      1.64     74.09                      126.68
# std        2466.94      0.48      0.08     14.05                       16.48
# min       10798.00      1.00      1.00     40.00                       90.00
# 25%       17662.00      1.00      1.59     65.00                      120.00
# 50%       19701.50      1.00      1.65     72.00                      120.00
# 75%       21324.00      2.00      1.70     82.00                      140.00
# max       23713.00      2.00      2.07    150.00                      210.00
# Simetria     -0.31      0.63     -0.06      0.86                        0.90
# Curtose      -0.82     -1.60      1.20      1.36                        1.43
#
#           Pressão sanguínea diastólica  Colesterol   Glicose      Fuma  \
# count                         68392.00    68392.00  68392.00  68392.00
# mean                             81.38        1.36      1.23      0.09
# std                               9.36        0.68      0.57      0.28
# min                              60.00        1.00      1.00      0.00
# 25%                              80.00        1.00      1.00      0.00
# 50%                              80.00        1.00      1.00      0.00
# 75%                              90.00        1.00      1.00      0.00
# max                             150.00        3.00      3.00      1.00
# Simetria                          0.43        1.60      2.40      2.91
# Curtose                           1.89        1.03      4.33      6.47
#
#             Álcool  Atividade física  \
# count     68392.00          68392.00
# mean          0.05              0.80
# std           0.22              0.40
# min           0.00              0.00
# 25%           0.00              1.00
# 50%           0.00              1.00
# 75%           0.00              1.00
# max           1.00              1.00
# Simetria      3.97             -1.53
# Curtose      13.77              0.33
#
#           Presença ou ausência de doença cardiovascular   Idade_2
# count                                          68392.00  68392.00
# mean                                               0.50     53.33
# std                                                0.50      6.76
# min                                                0.00     29.60
# 25%                                                0.00     48.40
# 50%                                                0.00     54.00
# 75%                                                1.00     58.40
# max                                                1.00     65.00
# Simetria                                           0.02     -0.31
# Curtose                                           -2.00     -0.82

# %%
Classe_curtose = pd.DataFrame(m.loc["Curtose"].apply(lambda x:
                  'leptocúrtica_pos' if (x > 0)
                   else ' mesocúrtica' if (x == 0)
                   else 'platicúrtica_neg')).T
Classe_curtose.rename(index={'Curtose': 'Classe curtose'}, inplace=True)

Classe_simetria = pd.DataFrame(m.loc["Simetria"].apply(lambda x:
                  'quase simétrica' if (((x > 0) & (x < 0.5)) | ((x < 0) & (x > -0.5))) 
                   else 'médio enviesado' if (((x > 0.5) & (x < 1.0)) | ((x < -0.5) & (x > -1.0))) 
                   else 'muito enviesado')).T
Classe_simetria.rename(index={'Simetria': 'Classe_simetria'}, inplace=True)

m = pd.concat([m, Classe_curtose, Classe_simetria], axis=0)
m.iloc[:,1:]
# Out:
#                             Idade            Gênero            Altura  \
# count                     68392.0           68392.0           68392.0
# mean                     19465.83              1.35              1.64
# std                       2466.94              0.48              0.08
# min                       10798.0               1.0               1.0
# 25%                       17662.0               1.0              1.59
# 50%                       19701.5               1.0              1.65
# 75%                       21324.0               2.0               1.7
# max                       23713.0               2.0              2.07
# Simetria                    -0.31              0.63             -0.06
# Curtose                     -0.82              -1.6               1.2
# Classe curtose   platicúrtica_neg  platicúrtica_neg  leptocúrtica_pos
# Classe_simetria   quase simétrica   médio enviesado   quase simétrica
#
#                              Peso Pressão arterial sistólica  \
# count                     68392.0                    68392.0
# mean                        74.09                     126.68
# std                         14.05                      16.48
# min                          40.0                       90.0
# 25%                          65.0                      120.0
# 50%                          72.0                      120.0
# 75%                          82.0                      140.0
# max                         150.0                      210.0
# Simetria                     0.86                        0.9
# Curtose                      1.36                       1.43
# Classe curtose   leptocúrtica_pos           leptocúrtica_pos
# Classe_simetria   médio enviesado            médio enviesado
#
#                 Pressão sanguínea diastólica        Colesterol  \
# count                                68392.0           68392.0
# mean                                   81.38              1.36
# std                                     9.36              0.68
# min                                     60.0               1.0
# 25%                                     80.0               1.0
# 50%                                     80.0               1.0
# 75%                                     90.0               1.0
# max                                    150.0               3.0
# Simetria                                0.43               1.6
# Curtose                                 1.89              1.03
# Classe curtose              leptocúrtica_pos  leptocúrtica_pos
# Classe_simetria              quase simétrica   muito enviesado
#
#                           Glicose              Fuma            Álcool  \
# count                     68392.0           68392.0           68392.0
# mean                         1.23              0.09              0.05
# std                          0.57              0.28              0.22
# min                           1.0               0.0               0.0
# 25%                           1.0               0.0               0.0
# 50%                           1.0               0.0               0.0
# 75%                           1.0               0.0               0.0
# max                           3.0               1.0               1.0
# Simetria                      2.4              2.91              3.97
# Curtose                      4.33              6.47             13.77
# Classe curtose   leptocúrtica_pos  leptocúrtica_pos  leptocúrtica_pos
# Classe_simetria   muito enviesado   muito enviesado   muito enviesado
#
#                  Atividade física  \
# count                     68392.0
# mean                          0.8
# std                           0.4
# min                           0.0
# 25%                           1.0
# 50%                           1.0
# 75%                           1.0
# max                           1.0
# Simetria                    -1.53
# Curtose                      0.33
# Classe curtose   leptocúrtica_pos
# Classe_simetria   muito enviesado
#
#                 Presença ou ausência de doença cardiovascular  \
# count                                                 68392.0
# mean                                                      0.5
# std                                                       0.5
# min                                                       0.0
# 25%                                                       0.0
# 50%                                                       0.0
# 75%                                                       1.0
# max                                                       1.0
# Simetria                                                 0.02
# Curtose                                                  -2.0
# Classe curtose                               platicúrtica_neg
# Classe_simetria                               quase simétrica
#
#                           Idade_2
# count                     68392.0
# mean                        53.33
# std                          6.76
# min                          29.6
# 25%                          48.4
# 50%                          54.0
# 75%                          58.4
# max                          65.0
# Simetria                    -0.31
# Curtose                     -0.82
# Classe curtose   platicúrtica_neg
# Classe_simetria   quase simétrica

# %% [markdown]
# ## 4.3 Checkpoint

# %%
# cópia do data set
data_clean = data_no_outliers.copy()

# %%
# salvar o data set 
data_clean.to_csv('data_clean.csv', index=False)

# checar a dimensão do data set 
data_clean.shape
# Out:
# (68392, 14)

# %% [markdown]
# ## 4.4 Mapa de Hipóteses

# %%
# Imagem do mapa de hipóteses
Image( 'Presença ou ausência de Doença Cardiovascular.jpg' )

# %% [markdown]
# ## 4.5 Engenharia de Recursos
#
# Vamos adicionar ferramentas para facilitar os modelos de Machine Learning futuros e obter melhores resultados.

# %% [markdown]
# ### 4.5.1 Carregando

# %%
# Carregar o data set
data1 = pd.read_csv('data_saves/data_clean.csv', low_memory=False)

# checar a dimensão do data set 
data1.shape
# Out:
# (68392, 14)

# %% [markdown]
# ### 4.5.2 Tabela Pressões

# %%
# Criando features adicionais
data1['TabelaPressões'] = ''
for idx, _ in data1.iterrows():
    if (data1['Pressão arterial sistólica'].at[idx]<120) & (data1['Pressão sanguínea diastólica'].at[idx]<80):
        data1['TabelaPressões'].at[idx]='Normal'
    elif (data1['Pressão arterial sistólica'].at[idx]<140) | (data1['Pressão sanguínea diastólica'].at[idx]<90):
        data1['TabelaPressões'].at[idx]='PreHipertensão'
    elif (data1['Pressão arterial sistólica'].at[idx]<160) | (data1['Pressão sanguínea diastólica'].at[idx]<100):
        data1['TabelaPressões'].at[idx]='Hipertensão1'
    elif (data1['Pressão arterial sistólica'].at[idx]<=180) |(data1['Pressão sanguínea diastólica'].at[idx]<=110):
        data1['TabelaPressões'].at[idx]='Hipertensão2'
    else:
        data1['TabelaPressões'].at[idx]='CriseHipertensiva'

# %%
data1.head()
# Out:
#    Idade  Gênero  Altura  Peso  Pressão arterial sistólica  \
# 0  18393   Homem    1.68  62.0                         110
# 1  20228  Mulher    1.56  85.0                         140
# 2  18857  Mulher    1.65  64.0                         130
# 3  17623   Homem    1.69  82.0                         150
# 4  17474  Mulher    1.56  56.0                         100
#
#    Pressão sanguínea diastólica  Colesterol  Glicose  Fuma  Álcool  \
# 0                            80           1        1     0       0
# 1                            90           3        1     0       0
# 2                            70           3        1     0       0
# 3                           100           1        1     0       0
# 4                            60           1        1     0       0
#
#    Atividade física  Presença ou ausência de doença cardiovascular  \
# 0                 1                                              0
# 1                 1                                              1
# 2                 0                                              1
# 3                 1                                              1
# 4                 0                                              0
#
#    TabelaPressões        IMC  TabelaIMC  Diferença_IMC
# 0  PreHipertensão  21.967120     Normal       0.967120
# 1    Hipertensão1  34.927679  Obesidade      13.927679
# 2  PreHipertensão  23.507805     Normal       2.507805
# 3    Hipertensão1  28.710479  Sobrepeso       7.710479
# 4          Normal  23.011177     Normal       2.011177

# %% [markdown]
# ### 4.5.3 Índice Massa Corpórea(IMC)

# %%
Altura_quadrado = (data1['Altura']*data1['Altura'])
Altura_quadrado
# Out:
# 0        2.8224
# 1        2.4336
# 2        2.7225
# 3        2.8561
# 4        2.4336
#           ...
# 68387    2.8224
# 68388    2.4964
# 68389    3.3489
# 68390    2.6569
# 68391    2.8900
# Name: Altura, Length: 68392, dtype: float64

# %%
# Criando features adicionais
data1['IMC'] = np.divide(data1['Peso'], Altura_quadrado)
data1.head()
# Out:
#    Idade  Gênero  Altura  Peso  Pressão arterial sistólica  \
# 0  18393   Homem    1.68  62.0                         110
# 1  20228  Mulher    1.56  85.0                         140
# 2  18857  Mulher    1.65  64.0                         130
# 3  17623   Homem    1.69  82.0                         150
# 4  17474  Mulher    1.56  56.0                         100
#
#    Pressão sanguínea diastólica  Colesterol  Glicose  Fuma  Álcool  \
# 0                            80           1        1     0       0
# 1                            90           3        1     0       0
# 2                            70           3        1     0       0
# 3                           100           1        1     0       0
# 4                            60           1        1     0       0
#
#    Atividade física  Presença ou ausência de doença cardiovascular  \
# 0                 1                                              0
# 1                 1                                              1
# 2                 0                                              1
# 3                 1                                              1
# 4                 0                                              0
#
#    TabelaPressões        IMC  TabelaIMC  Diferença_IMC
# 0  PreHipertensão  21.967120     Normal       0.967120
# 1    Hipertensão1  34.927679  Obesidade      13.927679
# 2  PreHipertensão  23.507805     Normal       2.507805
# 3    Hipertensão1  28.710479  Sobrepeso       7.710479
# 4          Normal  23.011177     Normal       2.011177

# %%
# Criando features adicionais
data1['TabelaIMC'] = ''
for idx, _ in data1.iterrows():
    if (data1['IMC'].at[idx]<18.5):
        data1['TabelaIMC'].at[idx]='Abaixo do Peso'
    elif (data1['IMC'].at[idx]>=18.5) & (data1['IMC'].at[idx]<=24.9):
        data1['TabelaIMC'].at[idx]='Normal'
    elif (data1['IMC'].at[idx]>25) & (data1['IMC'].at[idx]<=29.9):
        data1['TabelaIMC'].at[idx]='Sobrepeso'
    else:
        data1['TabelaIMC'].at[idx]='Obesidade'

# %%
# Valor padrão de IMC
IMC_Normal = 21

# Criando features adicionais
data1['Diferença_IMC'] = data1['IMC'] - IMC_Normal
data1.head()
# Out:
#    Idade  Gênero  Altura  Peso  Pressão arterial sistólica  \
# 0  18393   Homem    1.68  62.0                         110
# 1  20228  Mulher    1.56  85.0                         140
# 2  18857  Mulher    1.65  64.0                         130
# 3  17623   Homem    1.69  82.0                         150
# 4  17474  Mulher    1.56  56.0                         100
#
#    Pressão sanguínea diastólica  Colesterol  Glicose  Fuma  Álcool  \
# 0                            80           1        1     0       0
# 1                            90           3        1     0       0
# 2                            70           3        1     0       0
# 3                           100           1        1     0       0
# 4                            60           1        1     0       0
#
#    Atividade física  Presença ou ausência de doença cardiovascular  \
# 0                 1                                              0
# 1                 1                                              1
# 2                 0                                              1
# 3                 1                                              1
# 4                 0                                              0
#
#    TabelaPressões        IMC  TabelaIMC  Diferença_IMC
# 0  PreHipertensão  21.967120     Normal       0.967120
# 1    Hipertensão1  34.927679  Obesidade      13.927679
# 2  PreHipertensão  23.507805     Normal       2.507805
# 3    Hipertensão1  28.710479  Sobrepeso       7.710479
# 4          Normal  23.011177     Normal       2.011177

# %% [markdown]
# ### 4.5.4 Checkpoint

# %%
# salvar o data set 
data1.to_csv('data1_f.csv', index=False)

# %% [markdown]
# # 5 Questões e Hipóteses

# %% [markdown]
# **1**. Pessoas que fumam tem mais chances de ter Doença Cardiovascular
#
# **2**. Mulheres tem mais chances de ter Doença Cardiovascular
#
# **3**. Pessoas que fumam e bebem tem mais chances de ter Doença Cardiovascular
#
# **4**. Pessoas que não fazem atividade física tem mais chances de ter Doença Cardiovascular
#
# **5**. Pessoas mais pesadas tem mais chances de ter Doença Cardiovascular

# %% [markdown]
# # 6 Análise Exploratória dos Dados

# %% [markdown]
# ## 6.1 Análises Univariadas

# %% [markdown]
# ### 6.1.1 Variável Alvo

# %% [markdown]
# Nossas respostas, de acordo com o gráfico, são bem equilibradas facilitando as aplicações dos modelos de Machine Learning.

# %%
plt.figure(figsize=(18,10))
ax1 = sns.histplot(x=data1['Presença ou ausência de doença cardiovascular'])
data_load(ax1,'Presença ou ausência de doença cardiovascular', 'Presença ou ausência de doença cardiovascular','Quantidade' )

# %% [markdown]
# ### 6.1.2 Variável Numérica

# %% [markdown]
# Gráficos bem próximos da distribuição Gaussiana(Normal).

# %%
plt.figure(figsize=(18,10))

# Idade
plt.subplot(3,3,1)
ax1 = sns.histplot(x=data1['Idade'],bins=50, kde=True)
data_load(ax1,'Idade', 'Idade','Quantidade' )

# Altura
plt.subplot(3,3,2)
ax2 = sns.histplot(x=data1['Altura'],bins=50, kde=True)
data_load(ax2,'Altura', 'Altura','Quantidade' )

# Peso
plt.subplot(3,3,3)
ax3 = sns.histplot(x=data1['Peso'],bins=50, kde=True)
data_load(ax3,'Peso', 'Peso','Quantidade' )

# Pressão arterial sistólica
plt.subplot(3,3,4)
ax4 = sns.histplot(x=data1['Pressão arterial sistólica'],bins=50, kde=True)
data_load(ax4,'Pressão arterial sistólica', 'Pressão arterial sistólica','Quantidade' )

# Pressão sanguínea diastólica
plt.subplot(3,3,5)
ax5 = sns.histplot(x=data1['Pressão sanguínea diastólica'],bins=50, kde=True)
data_load(ax5,'Pressão sanguínea diastólica', 'Pressão sanguínea diastólica','Quantidade' )

# IMC
plt.subplot(3,3,6)
ax3 = sns.histplot(x=data1['IMC'],bins=50, kde=True)
data_load(ax6,'IMC', 'IMC','Quantidade' )

# Diferença_IMC
plt.subplot(3,3,7)
ax3 = sns.histplot(x=data1['Diferença_IMC'],bins=50, kde=True)
data_load(ax7,'Diferença_IMC', 'Diferença_IMC','Quantidade' )

plt.subplots_adjust(hspace=0.3)  
  
    
plt.show()

# %% [markdown]
# ### 6.1.3 Variável Categórica

# %%
plt.figure(figsize=(18, 10))

# Gênero
plt.subplot(3,3,1)
ax1 = sns.countplot(x=data1['Gênero'])
data_load(ax1,'Gênero', 'Gênero','Quantidade' )

# Colesterol
plt.subplot(3,3,2)
ax2 = sns.countplot(x=data1['Colesterol'])
data_load(ax2,'Colesterol', 'Colesterol','Quantidade' )

# Glicose
plt.subplot(3,3,3)
ax3 = sns.countplot(x=data1['Glicose'])
data_load(ax3,'Glicose', 'Glicose','Quantidade' )

# Fuma
plt.subplot(3,3,4)
ax4 = sns.countplot(x=data1['Fuma'])
data_load(ax4,'Fuma', 'Fuma','Quantidade' )

# Álcool
plt.subplot(3,3,5)
ax5 = sns.countplot(x=data1['Álcool'])
data_load(ax5,'Álcool', 'Álcool','Quantidade' )

# Atividade física
plt.subplot(3,3,6)
ax6 = sns.countplot(x=data1['Atividade física'])
data_load(ax6,'Atividade física', 'Atividade física','Quantidade' )

# Presença ou ausência de doença cardiovascular
plt.subplot(3,3,7)
ax7 = sns.countplot(x=data1['Presença ou ausência de doença cardiovascular'])
data_load(ax7,'Presença ou ausência de doença cardiovascular', 'Presença ou ausência de doença cardiovascular','Quantidade' )

# TabelaPressões
plt.subplot(3,3,8)
ax8 = sns.countplot(x=data1['TabelaPressões'])
data_load(ax8,'TabelaPressões', 'TabelaPressões','Quantidade' )

# TabelaIMC
plt.subplot(3,3,9)
ax9 = sns.countplot(x=data1['TabelaIMC'])
data_load(ax9,'TabelaIMC', 'TabelaIMC','Quantidade' )

ax8.tick_params(axis='x', rotation=45)

plt.subplots_adjust(hspace=0.5)
  
plt.show()

# %% [markdown]
# ## 6.2 Análises Bivariadas

# %% [markdown]
# ## H1
# Pessoas que fumam tem mais chances de ter Doença Cardiovascular - **FALSO**

# %% [markdown]
# Tanto pessoas que fumam, quanto pessoas que não fumam, tem chances de terem Doença Cardiovascular.

# %%
plt.figure(figsize=(18, 10))
plt.subplot(1,1,1)
ax1 = sns.countplot(x=data1['Fuma'], hue=data1['Presença ou ausência de doença cardiovascular'])
data_load(ax1,'Pessoas que fumam tem mais chances de ter Doença Cardiovascular', 'Fuma','Quantidade' )

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# ## H2
# Mulheres tem mais chances de ter Doença Cardiovascular - **FALSO**

# %% [markdown]
# De acordo com o gráfico, mulheres tem menos chance de ter Doença Cardiovascular que os homens.

# %%
plt.figure(figsize=(18, 10))
plt.subplot(1,1,1)
ax2 = sns.countplot(x=data1['Gênero'], hue=data1['Presença ou ausência de doença cardiovascular'])
data_load(ax2,'Mulheres tem mais chances de ter Doença Cardiovascular', 'Gênero','Quantidade' )

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# ## H3
# Pessoas mais pesadas tem mais chances de ter Doença Cardiovascular - **VERDADEIRO**

# %% [markdown]
# Pessoas com Doença Cardiovascular possuem, em sua maioria, peso entre 65kg e 85kg, diferente dos que não tem, no qual possuem entre 62kg e 79kg.

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1,1,1)
ax3 = sns.boxplot(data = data1 , x="Presença ou ausência de doença cardiovascular", y="Peso")
data_load(ax3,'Pessoas mais pesadas tem mais chances de ter Doença Cardiovascular', 'Presença ou ausência de doença cardiovascular','Peso' )

plt.subplots_adjust(hspace=0.5)

plt.show()

# %% [markdown]
# ## H4
# Pessoas que não fazem atividade física tem muito mais chances de ter Doença Cardiovascular - **FALSO**

# %% [markdown]
# De acordo com o gráfico, pessoas que não fazem atividade física tem mais chances de ter Doença Cardiovascular, mas não numa diferença grande.

# %%
plt.figure(figsize=(18, 10))
plt.subplot(1,1,1)
ax4 = sns.countplot(x=data1['Atividade física'], hue=data1['Presença ou ausência de doença cardiovascular'])
data_load(ax4,'Pessoas que não fazem atividade física tem mais chances de ter Doença Cardiovascular', 'Atividade física','Quantidade' )

plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# ## H5
# Pessoas que fumam e bebem simultaneamente tem mais chances de ter doença cardiovascular - **FALSO**

# %% [markdown]
# Pessoas que fumam e bebem simultaneamente tem menos quantidade populacional diagnosticada com Doença Cardiovascular.

# %%
f, ax = plt.subplots(1,2, figsize=(10,5))
H5 = data1.loc[(data1['Fuma'] == 1) & (data1['Álcool'] == 1)]

data['Presença ou ausência de doença cardiovascular'].value_counts().plot.pie(ax=ax[0], explode=[0.02, 0.02], autopct='%0.2f%%')

H5['Presença ou ausência de doença cardiovascular'].value_counts().plot.pie(ax=ax[1], explode=[0.02, 0.02], autopct='%0.2f%%')

data_load(ax[0],'Pessoas com DCV ou não', '','' )
data_load(ax[1],'Pessoas que fumam e bebem com DCV ou não', '','' )

plt.subplots_adjust(hspace=0.5)
f.tight_layout()
plt.show()

# %% [markdown]
# ### 6.2.1 Visão Global das Hipóteses

# %%
tab =[['Hypothesis', 'Conclusion', 'Relevance', 'Discover'],
      ['H1', 'Falso', 'Médio', 'Pessoas que fumam tem mais chances de ter Doença Cardiovascular.'],  
      ['H2', 'Falso', 'Médio', 'Mulheres tem mais chances de ter Doença Cardiovascular.'],  
      ['H3', 'Verdadeiro', 'Alto', 'Pessoas mais pesadas tem mais chances de ter Doença Cardiovascular.'],
      ['H4', 'Falso', 'Médio', 'Pessoas que não fazem atividade física tem muito mais chances de ter Doença Cardiovascular.'],
      ['H5', 'Falso', 'Alto', 'Pessoas que fumam e bebem simultaneamente tem mais chances de ter doença cardiovascular.']
     ]

print( tabulate( tab, headers='firstrow' ) )
# Out:
# Hypothesis    Conclusion    Relevance    Discover
# ------------  ------------  -----------  -------------------------------------------------------------------------------------------
# H1            Falso         Médio        Pessoas que fumam tem mais chances de ter Doença Cardiovascular.
# H2            Falso         Médio        Mulheres tem mais chances de ter Doença Cardiovascular.
# H3            Verdadeiro    Alto         Pessoas mais pesadas tem mais chances de ter Doença Cardiovascular.
# H4            Falso         Médio        Pessoas que não fazem atividade física tem muito mais chances de ter Doença Cardiovascular.
# H5            Falso         Alto         Pessoas que fumam e bebem simultaneamente tem mais chances de ter doença cardiovascular.

# %% [markdown]
# ## 6.3 Análises Multivariadas

# %% [markdown]
# Vamos dividir os atributos em categóricos, numérico e binários para fazer correlações entre eles e excluir a ferramenta **Idade_2** por não ter mais utilidade.

# %% [markdown]
# ### 6.3.1 Dtypes

# %% [markdown]
# Dados Numéricos:
#
# * <code> Idade <code>
# * <code> Altura <code>
# * <code> Peso <code>
# * <code> Pressão arterial sistólica <code>
# * <code> Pressão sanguínea diastólica <code>
# * <code> IMC <code>
# * <code> Diferença_IMC <code>
#
# Dados Categóricos:
#
# * <code> Gênero <code>
# * <code> Colesterol <code>
# * <code> Glicose <code>
# * <code> TabelaPressões <code>
# * <code> TabelaIMC <code>
#
# Dados Binários:
#
# * <code> Fuma <code>
# * <code> Álcool <code>
# * <code> Atividade física <code>

# %%
data1 = pd.read_csv('data_saves/data1_f.csv', low_memory=False)

# %%
# Removendo id e idade_2
data1 = data1.drop(['id', 'Idade_2'], axis=1)
data1.head()

# Dividindo os dados em binary, numerical e categorical
categorical = data1[['Gênero','Colesterol', 'Glicose', 'TabelaPressões', 'TabelaIMC']]
numerical = data1[['Idade','Altura', 'Peso', 'Pressão arterial sistólica', 'Pressão sanguínea diastólica', 'IMC', 'Diferença_IMC']]
binary = data1[['Fuma','Álcool', 'Atividade física']]

# %%
# Alterando os valores dos dados categorical 
categorical['Gênero'] = categorical['Gênero'].replace({ 1: 'mulher', 2: 'homem'})
categorical['Colesterol'] = categorical['Colesterol'].replace({ 1: 'normal', 2: 'acima normal', 3: 'muito acima'})
categorical['Glicose'] = categorical['Glicose'].replace({1: 'normal', 2: 'acima normal', 3: 'muito acima'})

# Mudando o dtype para dados categorical
categorical['Gênero'] = categorical['Gênero'].astype('category')
categorical['Colesterol'] = categorical['Colesterol'].astype('category')
categorical['Glicose'] = categorical['Glicose'].astype('category')

# %% [markdown]
# ### 6.3.2 Atributos Categóricos

# %% [markdown]
# Usando o método estatístico do qui-quadrado, fizemos as correlações entre variáveis categóricas e colocamos num mapa de calor. Nesse mapa, a melhor correlação achada foi entre taxa de glicose e colesterol.

# %%
# Atribuindo variáveis para os dados categorical
a1 = categorical['Gênero']
a2 = categorical['Colesterol']
a3 = categorical['Glicose']
a4 = categorical['TabelaIMC']
a5 = categorical['TabelaPressões']


# Correlação entre os dados categorical
x1 = UG.cramerv(a1, a1)
x2 = UG.cramerv(a1, a2)
x3 = UG.cramerv(a1, a3)
x4 = UG.cramerv(a1, a4)
x5 = UG.cramerv(a1, a5)

x6 = UG.cramerv(a2, a1)
x7 = UG.cramerv(a2, a2)
x8 = UG.cramerv(a2, a3)
x9 = UG.cramerv(a2, a4)
x10 = UG.cramerv(a2, a5)

x11 = UG.cramerv(a3, a1)
x12 = UG.cramerv(a3, a2)
x13 = UG.cramerv(a3, a3)
x14 = UG.cramerv(a3, a4)
x15 = UG.cramerv(a3, a5)

x16 = UG.cramerv(a4, a1)
x17 = UG.cramerv(a4, a2)
x18 = UG.cramerv(a4, a3)
x19 = UG.cramerv(a4, a4)
x20 = UG.cramerv(a4, a5)

x21 = UG.cramerv(a5, a1)
x22 = UG.cramerv(a5, a2)
x23 = UG.cramerv(a5, a3)
x24 = UG.cramerv(a5, a4)
x25 = UG.cramerv(a5, a5)

# DataFrame para armazenar os valores da correlação
data1_cramerv = pd.DataFrame({'Gênero': [x1, x2, x3, x4, x5],
                            'Colesterol':[x6, x7, x8, x9, x10],
                            'Glicose':[x11, x12, x13, x14, x15],
                            'TabelaIMC':[x16, x17, x18, x19, x20],
                            'TabelaPressões  ':[x21, x22, x23, x24, x25]})

# colocar os índices igual as colunas
data1_cramerv = data1_cramerv.set_index(data1_cramerv.columns)
data1_cramerv
# Out:
#                     Gênero  Colesterol   Glicose  TabelaIMC  TabelaPressões
# Gênero            0.999975    0.037348  0.021597   0.107947          0.080778
# Colesterol        0.037348    1.000015  0.392732   0.116524          0.127081
# Glicose           0.021597    0.392732  1.000015   0.088605          0.069156
# TabelaIMC         0.107947    0.116524  0.088605   1.000022          0.128243
# TabelaPressões    0.080778    0.127081  0.069156   0.128243          1.000029

# %%
# Plotando a correlação
fig, ax = plt.subplots()

ax.figure.set_size_inches(16, 6)

plt.subplot(1,2,1)

TrueFalse = np.triu(np.ones_like(data1_cramerv, dtype=np.bool))
sns.heatmap(data1_cramerv, mask=TrueFalse, linewidths=.5, annot=True, annot_kws={"fontsize":14}, cmap='viridis')
plt.title("CramerV")

plt.show()

# %% [markdown]
# ### 6.3.3 Atributos Numéricos

# %% [markdown]
# Nos atributos numéricos, usamos a correlação de Pearson num mapa de calor. Nesse mapa, observamos uma correlação maior entre elas.

# %%
# Correlação entre dados int e float
NA = numerical.select_dtypes(['int64','int32', 'float64'])
correlation = NA.corr( method='pearson' )
plt.figure( figsize=(20, 10) )
ax1 = sns.heatmap(data=correlation, annot=True, fmt='.2f', annot_kws={'fontsize':14, 'fontweight':'bold'})
ax1.set_xticklabels(correlation, fontsize=15)
ax1.set_yticklabels(correlation, fontsize=15)
data_load(ax1, 'Mapa de Calor de Atributos Numéricos', '', '')

# %% [markdown]
# ### 6.3.4 Atributos Numéricos e Atributos Categóricos

# %% [markdown]
# Nos atributos abaixo, fizemos a correlação entre os dados binários e numéricos através do método do ponto-bisserial. De acordo com o mapa, as relações entre elas também deram um pouco baixas.

# %%
# Atribuindo variáveis para os dados numerical e binary
a1 = numerical['Idade']
a2 = numerical['Altura']
a3 = numerical['Peso']
a4 = numerical['Pressão arterial sistólica']
a5 = numerical['Pressão sanguínea diastólica']
a6 = numerical['IMC']
a7 = numerical['Diferença_IMC']
a8 = binary['Fuma']
a9 = binary['Álcool']
a10 = binary['Atividade física']

# Correlação entre os dados numerical e categorical
x1 = pointbiserialr(a8, a1)[0]
x2 = pointbiserialr(a8, a2)[0]
x3 = pointbiserialr(a8, a3)[0]
x4 = pointbiserialr(a8, a4)[0]
x5 = pointbiserialr(a8, a5)[0]
x6 = pointbiserialr(a8, a6)[0]
x7 = pointbiserialr(a8, a7)[0]
    
x8 = pointbiserialr(a9, a1)[0]
x9 = pointbiserialr(a9, a2)[0]
x10 = pointbiserialr(a9, a3)[0]
x11 = pointbiserialr(a9, a4)[0]
x12 = pointbiserialr(a9, a5)[0]
x13 = pointbiserialr(a9, a6)[0]
x14 = pointbiserialr(a9, a7)[0]
    

x15 = pointbiserialr(a10,a1)[0]
x16 = pointbiserialr(a10, a2)[0]
x17 = pointbiserialr(a10,a3)[0]
x18 = pointbiserialr(a10, a4)[0]
x19 = pointbiserialr(a10, a5)[0]
x20 = pointbiserialr(a10, a6)[0]
x21 = pointbiserialr(a10, a7)[0]

# %%
# Plotando a correlação
data1_pbs_r = pd.DataFrame({'Fuma':[x1, x2, x3, x4, x5, x6, x7],
                         'Álcool':[x8, x9, x10, x11, x12, x13, x14],
                         'Atividade física':[x15, x16, x17, x18, x19, x20, x21]})

data1_pbs_r = data1_pbs_r.set_index(numerical.columns)


fig, ax = plt.subplots()

ax.figure.set_size_inches(14, 8)

plt.subplot(1,2,1)
sns.heatmap(data1_pbs_r, annot=True, annot_kws={"fontsize":14}, cmap='viridis')
plt.title("Ponto Bisserial")

plt.show()

# %% [markdown]
# # 7 Preparação dos Dados

# %% [markdown]
# * Reescalamos os dados numéricos para equilibrar os níveis de importâncias em relação à ferramentas com escalas mais baixas.
# * Codificamos os dados binários ja que não existe nível de importância entre eles.
# * Colocamos em quantidade de frequência em relaçao à quantidade total os dados categóricos.

# %%
# Carregar o data set
data1 = pd.read_csv('data_saves/data1_f.csv', low_memory=False)

# salvar o id para usar depois
data1_id = [['id']]

# remover colunas inúteis
data1.drop(['id','Idade_2'], axis=1, inplace=True)

# checar a dimensão do data set
data1.shape
# Out:
# (68392, 16)

# %%
data1
# Out:
#        Idade  Gênero  Altura   Peso  Pressão arterial sistólica  \
# 0      18393       2    1.68   62.0                         110
# 1      20228       1    1.56   85.0                         140
# 2      18857       1    1.65   64.0                         130
# 3      17623       2    1.69   82.0                         150
# 4      17474       1    1.56   56.0                         100
# ...      ...     ...     ...    ...                         ...
# 68387  19240       2    1.68   76.0                         120
# 68388  22601       1    1.58  126.0                         140
# 68389  19066       2    1.83  105.0                         180
# 68390  22431       1    1.63   72.0                         135
# 68391  20540       1    1.70   72.0                         120
#
#        Pressão sanguínea diastólica  Colesterol  Glicose  Fuma  Álcool  \
# 0                                80           1        1     0       0
# 1                                90           3        1     0       0
# 2                                70           3        1     0       0
# 3                               100           1        1     0       0
# 4                                60           1        1     0       0
# ...                             ...         ...      ...   ...     ...
# 68387                            80           1        1     1       0
# 68388                            90           2        2     0       0
# 68389                            90           3        1     0       1
# 68390                            80           1        2     0       0
# 68391                            80           2        1     0       0
#
#        Atividade física  Presença ou ausência de doença cardiovascular  \
# 0                     1                                              0
# 1                     1                                              1
# 2                     0                                              1
# 3                     1                                              1
# 4                     0                                              0
# ...                 ...                                            ...
# 68387                 1                                              0
# 68388                 1                                              1
# 68389                 0                                              1
# 68390                 0                                              1
# 68391                 1                                              0
#
#        TabelaPressões        IMC  TabelaIMC  Diferença_IMC
# 0      PreHipertensão  21.967120     Normal       0.967120
# 1        Hipertensão1  34.927679  Obesidade      13.927679
# 2      PreHipertensão  23.507805     Normal       2.507805
# 3        Hipertensão1  28.710479  Sobrepeso       7.710479
# 4              Normal  23.011177     Normal       2.011177
# ...               ...        ...        ...            ...
# 68387  PreHipertensão  26.927438  Sobrepeso       5.927438
# 68388    Hipertensão1  50.472681  Obesidade      29.472681
# 68389    Hipertensão1  31.353579  Obesidade      10.353579
# 68390  PreHipertensão  27.099251  Sobrepeso       6.099251
# 68391  PreHipertensão  24.913495  Obesidade       3.913495
#
# [68392 rows x 16 columns]

# %% [markdown]
# ## 7.1 treino e teste

# %%
# Alterando os valores da coluna Gênero
data1['Gênero'] = data1['Gênero'].apply(lambda x: 'Mulher' if x == 1 else 'Homem')

# Dividindo em treino e teste
X = data1.drop(['Presença ou ausência de doença cardiovascular'], axis=1)
y = data1[['Presença ou ausência de doença cardiovascular']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %%
train_scale = X_train[['Idade', 'Altura', 'Peso', 'Pressão arterial sistólica', 'Pressão sanguínea diastólica', 'IMC', 'Diferença_IMC']]
test_scale = X_test[['Idade', 'Altura', 'Peso', 'Pressão arterial sistólica', 'Pressão sanguínea diastólica', 'IMC', 'Diferença_IMC']]

# %% [markdown]
# ## 7.2 Reescalando

# %%
# Instanciando a normalização 
mm_scaler = MinMaxScaler()
mm_scaler.fit(train_scale)

# Reescalando os dados numerical
train_numerical = mm_scaler.transform(train_scale.values)
test_numerical = mm_scaler.transform(test_scale.values)

# %%
train_numerical_scaled = pd.DataFrame(train_numerical, columns=train_scale.columns)
test_numerical_scaled = pd.DataFrame(test_numerical, columns=test_scale.columns)

# %%
pickle.dump(mm_scaler, open('model/numerical_scaler.pkl', 'wb'))

# %% [markdown]
# ## 7.3 Transformação

# %%
# Selecionando a coluna Gênero
train_categorical = X_train[['Gênero']]
test_categorical = X_test[['Gênero']]

# Enumerando em ordem os índices
train_categorical.reset_index(drop=True, inplace=True)
test_categorical.reset_index(drop=True, inplace=True)

# Dividindo em valores binários 
train_cat_code = pd.get_dummies(train_categorical, drop_first=True)
test_cat_code = pd.get_dummies(test_categorical, drop_first=True)

# %%
# Selecionando as colunas binárias
train_binary = X_train[['Fuma','Álcool','Atividade física']]
test_binary = X_test[['Fuma','Álcool','Atividade física']]

# Enumerando em ordem os índices
train_binary = train_binary.reset_index(drop=True)
test_binary = test_binary.reset_index(drop=True)

# %% [markdown]
# ### 7.3.1 Frequência de treino

# %% [markdown]
# Primeiro são os dados de treino a serem colocados em frequência.

# %%
# Selecionando as colunas categorical
train_cat_ = X_train[['Colesterol','Glicose','TabelaIMC','TabelaPressões']]

# Enumerando em ordem os índices
train_cat_.reset_index(drop=True, inplace=True)

# %%
# Criado uma base de dados de frequência em relação ao total para Colesterol
cont_colesterol = train_cat_['Colesterol'].value_counts().to_dict()
data1_colesterol = pd.DataFrame(cont_colesterol.items(), columns=['Valor','Contagem'])
data1_colesterol['frequencia'] = data1_colesterol['Contagem'] / data1_colesterol['Contagem'].sum()

# Criado uma base de dados de frequência em relação ao total para Glicose
cont_glicose = train_cat_['Glicose'].value_counts().to_dict()
data1_glicose = pd.DataFrame(cont_glicose.items(), columns=['Valor','Contagem'])
data1_glicose['frequencia'] = data1_glicose['Contagem'] / data1_glicose['Contagem'].sum()

# Criado uma base de dados de frequência em relação ao total para TabelaIMC
cont_tabelaIMC = train_cat_['TabelaIMC'].value_counts().to_dict()
data1_tabelaIMC = pd.DataFrame(cont_tabelaIMC.items(), columns=['Valor','Contagem'])
data1_tabelaIMC['frequencia'] = data1_tabelaIMC['Contagem'] / data1_tabelaIMC['Contagem'].sum()

# Criado uma base de dados de frequência em relação ao total para TabelaPressões 
cont_tabelapressões = train_cat_['TabelaPressões'].value_counts().to_dict()
data1_tabelapressões = pd.DataFrame(cont_tabelapressões.items(), columns=['Valor','Contagem'])
data1_tabelapressões['frequencia'] = data1_tabelapressões['Contagem'] / data1_tabelapressões['Contagem'].sum()

# %%
# Transformando a base de dados de frequência criada em dicionário
freq_colesterol = data1_colesterol.set_index('Valor').to_dict()['frequencia']
freq_glicose = data1_glicose.set_index('Valor').to_dict()['frequencia']
freq_weight_status = data1_tabelaIMC.set_index('Valor').to_dict()['frequencia']
freq_tabelapressões = data1_tabelapressões.set_index('Valor').to_dict()['frequencia']

# %%
# Criando base de dados
train_cat_codificado = pd.DataFrame()

# Substituir os valores da base de dados real para as frequência obtidas
train_cat_codificado['Colesterol'] =  train_cat_['Colesterol'].map(freq_colesterol)
train_cat_codificado['Glicose'] =  train_cat_['Glicose'].map(freq_glicose)
train_cat_codificado['TabelaIMC'] =  train_cat_['TabelaIMC'].map(freq_weight_status)
train_cat_codificado['TabelaPressões'] =  train_cat_['TabelaPressões'].map(freq_tabelapressões)

# %% [markdown]
# ### 7.3.2 Transformação de treino

# %%
# Concatenando os dados de transformação de treino
X_train_ = pd.concat([train_numerical_scaled, train_binary, train_cat_code, train_cat_codificado], axis=1)

# %% [markdown]
# ### 7.3.3 Frequência de teste

# %% [markdown]
# Em seguida são colocados em frequência os dados de teste.

# %%
# Selecionando as colunas categorical
test_cat_ = X_test[['Colesterol','Glicose','TabelaIMC','TabelaPressões']]

# Enumerando em ordem os índices
test_cat_.reset_index(drop=True, inplace=True)

# %%
# Criado uma base de dados de frequência em relação ao total para Colesterol
cont_colesterol = test_cat_['Colesterol'].value_counts().to_dict()
data1_colesterol = pd.DataFrame(cont_colesterol.items(), columns=['Valor','Contagem'])
data1_colesterol['frequencia'] = data1_colesterol['Contagem'] / data1_colesterol['Contagem'].sum()

# Criado uma base de dados de frequência em relação ao total para Glicose
cont_glicose = test_cat_['Glicose'].value_counts().to_dict()
data1_glicose = pd.DataFrame(cont_glicose.items(), columns=['Valor','Contagem'])
data1_glicose['frequencia'] = data1_glicose['Contagem'] / data1_glicose['Contagem'].sum()

# Criado uma base de dados de frequência em relação ao total para TabelaIMC
cont_tabelaIMC = test_cat_['TabelaIMC'].value_counts().to_dict()
data1_tabelaIMC = pd.DataFrame(cont_tabelaIMC.items(), columns=['Valor','Contagem'])
data1_tabelaIMC['frequencia'] = data1_tabelaIMC['Contagem'] / data1_tabelaIMC['Contagem'].sum()

# Criado uma base de dados de frequência em relação ao total para TabelaPressões
cont_tabelapressões = test_cat_['TabelaPressões'].value_counts().to_dict()
data1_tabelapressões = pd.DataFrame(cont_tabelapressões.items(), columns=['Valor','Contagem'])
data1_tabelapressões['frequencia'] = data1_tabelapressões['Contagem'] / data1_tabelapressões['Contagem'].sum()

# %%
# Transformando a base de dados de frequência criada em dicionário
freq_colesterol = data1_colesterol.set_index('Valor').to_dict()['frequencia']
freq_glicose = data1_glicose.set_index('Valor').to_dict()['frequencia']
freq_weight_status = data1_tabelaIMC.set_index('Valor').to_dict()['frequencia']
freq_tabelapressões = data1_tabelapressões.set_index('Valor').to_dict()['frequencia']

# %%
# Criando base de dados
test_cat_codificado = pd.DataFrame()

# Substituir os valores da base de dados real para as frequência obtidas
test_cat_codificado['Colesterol'] =  test_cat_['Colesterol'].map(freq_colesterol)
test_cat_codificado['Glicose'] =  test_cat_['Glicose'].map(freq_glicose)
test_cat_codificado['TabelaIMC'] =  test_cat_['TabelaIMC'].map(freq_weight_status)
test_cat_codificado['TabelaPressões'] =  test_cat_['TabelaPressões'].map(freq_tabelapressões)

# %% [markdown]
# ### 7.3.4 Transformação de teste

# %%
# Concatenando os dados de transformação de teste
X_test_ = pd.concat([test_numerical_scaled, test_binary, test_cat_code, test_cat_codificado], axis=1)

# %% [markdown]
# ## 7.4 Checkpoint

# %%
X_train_.to_csv('data_saves/data1_train_.csv', index=False)
X_test_.to_csv('data_saves/data1_test_.csv', index=False)

# %% [markdown]
# # 8 Seleção de Recursos

# %% [markdown]
# Testamos para selecionar as melhores ferramentas o método do Boruta e o Extra Tree Classifier. O melhor resultado obtido foi pelo método Boruta, então o usamos.

# %% [markdown]
# ## 8.1 Extra Tree Classifier

# %%
# Instanciando o ExtraTreesClassifier
forest = en.ExtraTreesClassifier(n_estimators=250, random_state=43, n_jobs=-1)

# Treinando pelo ExtraTreesClassifier
forest.fit(X_train_, y_train)
# Out:
# ExtraTreesClassifier(n_estimators=250, n_jobs=-1, random_state=43)

# %%
# a importância de cada feature de acordo com o modelo(média)
importat_features = forest.feature_importances_

# Ranking das features
print('Ranking de Ferramenta: ')
ranking = pd.DataFrame()
for a, b in zip(X_train_, forest.feature_importances_):
    lista = pd.DataFrame({'Ferramenta': a, 'Importância': b}, index=[0])
    ranking = pd.concat([ranking,lista], axis=0)
    
print(ranking.sort_values('Importância', ascending=False))

# plotando os rankings das features
ax1 = sns.barplot(data=ranking.sort_values('Importância', ascending=False), x='Ferramenta', y='Importância' )
data_load(ax1, 'Ferramenta importância', '', 'Importância')
plt.xticks( rotation=90 );
# Out:
# Ranking de Ferramenta:
#                      Ferramenta  Importância
# 0                         Idade     0.238993
# 0    Pressão arterial sistólica     0.131027
# 0                 Diferença_IMC     0.101453
# 0                           IMC     0.101318
# 0                          Peso     0.097408
# 0                        Altura     0.093718
# 0  Pressão sanguínea diastólica     0.076559
# 0                TabelaPressões     0.049509
# 0                    Colesterol     0.042172
# 0                     TabelaIMC     0.014124
# 0                       Glicose     0.014092
# 0                 Gênero_Mulher     0.013602
# 0              Atividade física     0.011243
# 0                          Fuma     0.007814
# 0                        Álcool     0.006967

# %%
# desvio padrão de cada importância de features
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
# ordem de maiores índices por importância de features do maior para o menor
indices = np.argsort(importances)[::-1]

# %%
selecionar_colunas = list(ranking.sort_values('Importância', ascending=False)['Ferramenta'][:7])

x_train_et = X_train_[selecionar_colunas]
x_test_et = X_test_[selecionar_colunas]

# %% [markdown]
# ## 8.2 Boruta Selecionado

# %%
# Instanciando ExtraTreesClassifier e RandomForestClassifier
RF_classifier = RandomForestClassifier(n_jobs=-1)
ET_classifier = ExtraTreesClassifier(n_jobs=-1)

# %%
# Definindo Boruta
boruta = BorutaPy(ET_classifier, n_estimators='auto', verbose=2, random_state=42).fit(X_train_.values, y_train.values.ravel())
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	5
# Tentative: 	3
# Rejected: 	7
# Iteration: 	9 / 100
# Confirmed: 	5
# Tentative: 	3
# Rejected: 	7
# Iteration: 	10 / 100
# Confirmed: 	5
# Tentative: 	3
# Rejected: 	7
# Iteration: 	11 / 100
# Confirmed: 	5
# Tentative: 	3
# Rejected: 	7
# Iteration: 	12 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	13 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	14 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	15 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	16 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	17 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	18 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	19 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	20 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	21 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	22 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	23 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	24 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	25 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	26 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	27 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	28 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	29 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	30 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	31 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	32 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	33 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	34 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	35 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	36 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	37 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	38 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	39 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	40 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	41 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	42 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	43 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	44 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	45 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	46 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	47 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	48 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	49 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	50 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	51 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	52 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	53 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	54 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	55 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	56 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	57 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	58 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	59 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	60 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	61 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	62 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	63 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	64 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	65 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	66 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	67 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	68 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	69 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	70 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	71 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	72 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	73 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	74 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	75 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	76 / 100
# Confirmed: 	5
# Tentative: 	2
# Rejected: 	8
# Iteration: 	77 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	78 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	79 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	80 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	81 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	82 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	83 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	84 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	85 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	86 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	87 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	88 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	89 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	90 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	91 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	92 / 100
# Confirmed: 	6
# Tentative: 	1
# Rejected: 	8
# Iteration: 	93 / 100
# Confirmed: 	7
# Tentative: 	0
# Rejected: 	8
#
#
# BorutaPy finished running.
#
# Iteration: 	94 / 100
# Confirmed: 	7
# Tentative: 	0
# Rejected: 	8

# %%
# Ranking das features
cols_selected = boruta.support_.tolist()
cols_selected_boruta =X_train_.iloc[:, cols_selected].columns.to_list()
cols_selected_boruta
# Out:
# ['Idade',
#  'Peso',
#  'Pressão arterial sistólica',
#  'Pressão sanguínea diastólica',
#  'IMC',
#  'Diferença_IMC',
#  'TabelaPressões']

# %%
X_train_boruta = X_train_[cols_selected_boruta].copy()
X_test_boruta = X_test_[cols_selected_boruta].copy()

# %%
# Plotando o ranking das features
ET_classifier.fit(X_train_, y_train)

feat_importances = pd.Series(ET_classifier.feature_importances_, index=X_train_.columns)
feat_importances.sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 9 Machine Learning

# %% [markdown]
# #### 0 = Não possui Doença Cardiovascular
# #### 1 = Possui Doença Cardiovascular

# %% [markdown]
# ## 9.1 Classificadores

# %% [markdown]
# O algoritmo que melhor atende as necessidades dos pacientes de forma rápida e com uma precisão melhor é o **LGBMClassifier**, pois possui melhor acurácia do F1-Score que é o que procuramos, assim como uma porcentagem baixa de falsos negativos que é bastante importante para quem é paciente dessa empresa.

# %%
# Definir o threshold
THRESHOLD = 0.45

# Definir os classifiers
classifiers = [LogisticRegression(max_iter=220, random_state=42),
               RandomForestClassifier(random_state=42),
               xgb.XGBClassifier(random_state=42),
               BalancedRandomForestClassifier(random_state=42),
               CatBoostClassifier(random_state=42, verbose=False),
               KNeighborsClassifier(n_neighbors=5,  weights='distance',n_jobs=-1),
               SGDClassifier(loss='log', random_state=42, n_jobs=-1), 
               LGBMClassifier(random_state=42, n_jobs=-1), 
               GaussianNB()]

# Calcular as performances dos classifiers 
perfomance_dados = UG.performance_modelo(X_train_boruta, X_test_boruta, 
                                                y_train, y_test, 
                                                THRESHOLD, classifiers)
# Out:
# Training LogisticRegression...
# Training RandomForestClassifier...
# Training XGBClassifier...
# Training BalancedRandomForestClassifier...
# Training CatBoostClassifier...
# Training KNeighborsClassifier...
# Training SGDClassifier...
# Training LGBMClassifier...
# Training GaussianNB...

# %%
# Valores máximos de cada coluna
perfomance_dados.style.highlight_max(color='darkorange')
# Out:
# <style  type="text/css" >
# #T_5553a_row6_col2,#T_5553a_row6_col3,#T_5553a_row7_col4,#T_5553a_row7_col5,#T_5553a_row7_col6,#T_5553a_row8_col1{
#             background-color:  darkorange;
#         }</style><table id="T_5553a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >precision</th>        <th class="col_heading level0 col2" >recall</th>        <th class="col_heading level0 col3" >f1-Score</th>        <th class="col_heading level0 col4" >ROC AUC</th>        <th class="col_heading level0 col5" >accuracy</th>        <th class="col_heading level0 col6" >cohen kappa</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5553a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5553a_row0_col0" class="data row0 col0" >LogisticRegression</td>
#                         <td id="T_5553a_row0_col1" class="data row0 col1" >0.705042</td>
#                         <td id="T_5553a_row0_col2" class="data row0 col2" >0.702014</td>
#                         <td id="T_5553a_row0_col3" class="data row0 col3" >0.703525</td>
#                         <td id="T_5553a_row0_col4" class="data row0 col4" >0.774557</td>
#                         <td id="T_5553a_row0_col5" class="data row0 col5" >0.707946</td>
#                         <td id="T_5553a_row0_col6" class="data row0 col6" >0.415766</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_5553a_row1_col0" class="data row1 col0" >RandomForestClassifier</td>
#                         <td id="T_5553a_row1_col1" class="data row1 col1" >0.652401</td>
#                         <td id="T_5553a_row1_col2" class="data row1 col2" >0.704384</td>
#                         <td id="T_5553a_row1_col3" class="data row1 col3" >0.677396</td>
#                         <td id="T_5553a_row1_col4" class="data row1 col4" >0.727362</td>
#                         <td id="T_5553a_row1_col5" class="data row1 col5" >0.668835</td>
#                         <td id="T_5553a_row1_col6" class="data row1 col6" >0.338229</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_5553a_row2_col0" class="data row2 col0" >XGBClassifier</td>
#                         <td id="T_5553a_row2_col1" class="data row2 col1" >0.702651</td>
#                         <td id="T_5553a_row2_col2" class="data row2 col2" >0.706605</td>
#                         <td id="T_5553a_row2_col3" class="data row2 col3" >0.704623</td>
#                         <td id="T_5553a_row2_col4" class="data row2 col4" >0.774640</td>
#                         <td id="T_5553a_row2_col5" class="data row2 col5" >0.707581</td>
#                         <td id="T_5553a_row2_col6" class="data row2 col6" >0.415108</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_5553a_row3_col0" class="data row3 col0" >BalancedRandomForestClassifier</td>
#                         <td id="T_5553a_row3_col1" class="data row3 col1" >0.652525</td>
#                         <td id="T_5553a_row3_col2" class="data row3 col2" >0.706161</td>
#                         <td id="T_5553a_row3_col3" class="data row3 col3" >0.678284</td>
#                         <td id="T_5553a_row3_col4" class="data row3 col4" >0.727924</td>
#                         <td id="T_5553a_row3_col5" class="data row3 col5" >0.669347</td>
#                         <td id="T_5553a_row3_col6" class="data row3 col6" >0.339272</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row4" class="row_heading level0 row4" >8</th>
#                         <td id="T_5553a_row4_col0" class="data row4 col0" >CatBoostClassifier</td>
#                         <td id="T_5553a_row4_col1" class="data row4 col1" >0.704415</td>
#                         <td id="T_5553a_row4_col2" class="data row4 col2" >0.711197</td>
#                         <td id="T_5553a_row4_col3" class="data row4 col3" >0.707790</td>
#                         <td id="T_5553a_row4_col4" class="data row4 col4" >0.777385</td>
#                         <td id="T_5553a_row4_col5" class="data row4 col5" >0.710140</td>
#                         <td id="T_5553a_row4_col6" class="data row4 col6" >0.420255</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row5" class="row_heading level0 row5" >10</th>
#                         <td id="T_5553a_row5_col0" class="data row5 col0" >KNeighborsClassifier</td>
#                         <td id="T_5553a_row5_col1" class="data row5 col1" >0.648024</td>
#                         <td id="T_5553a_row5_col2" class="data row5 col2" >0.684686</td>
#                         <td id="T_5553a_row5_col3" class="data row5 col3" >0.665850</td>
#                         <td id="T_5553a_row5_col4" class="data row5 col4" >0.712870</td>
#                         <td id="T_5553a_row5_col5" class="data row5 col5" >0.660794</td>
#                         <td id="T_5553a_row5_col6" class="data row5 col6" >0.321961</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row6" class="row_heading level0 row6" >12</th>
#                         <td id="T_5553a_row6_col0" class="data row6 col0" >SGDClassifier</td>
#                         <td id="T_5553a_row6_col1" class="data row6 col1" >0.643123</td>
#                         <td id="T_5553a_row6_col2" class="data row6 col2" >0.818572</td>
#                         <td id="T_5553a_row6_col3" class="data row6 col3" >0.720318</td>
#                         <td id="T_5553a_row6_col4" class="data row6 col4" >0.774439</td>
#                         <td id="T_5553a_row6_col5" class="data row6 col5" >0.686234</td>
#                         <td id="T_5553a_row6_col6" class="data row6 col6" >0.374521</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row7" class="row_heading level0 row7" >14</th>
#                         <td id="T_5553a_row7_col0" class="data row7 col0" >LGBMClassifier</td>
#                         <td id="T_5553a_row7_col1" class="data row7 col1" >0.708868</td>
#                         <td id="T_5553a_row7_col2" class="data row7 col2" >0.711493</td>
#                         <td id="T_5553a_row7_col3" class="data row7 col3" >0.710178</td>
#                         <td id="T_5553a_row7_col4" class="data row7 col4" >0.780372</td>
#                         <td id="T_5553a_row7_col5" class="data row7 col5" >0.713356</td>
#                         <td id="T_5553a_row7_col6" class="data row7 col6" >0.426645</td>
#             </tr>
#             <tr>
#                         <th id="T_5553a_level0_row8" class="row_heading level0 row8" >16</th>
#                         <td id="T_5553a_row8_col0" class="data row8 col0" >GaussianNB</td>
#                         <td id="T_5553a_row8_col1" class="data row8 col1" >0.732018</td>
#                         <td id="T_5553a_row8_col2" class="data row8 col2" >0.587826</td>
#                         <td id="T_5553a_row8_col3" class="data row8 col3" >0.652045</td>
#                         <td id="T_5553a_row8_col4" class="data row8 col4" >0.755095</td>
#                         <td id="T_5553a_row8_col5" class="data row8 col5" >0.690328</td>
#                         <td id="T_5553a_row8_col6" class="data row8 col6" >0.379010</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 9.2 ROC AUC

# %% [markdown]
# Feito o gráfico da curva ROC, observamos como o modelo LGBMClassifier é bom comparado à reta sem habilidade.

# %%
# Instanciando LGBMClassifier
LGBMClassifier = LGBMClassifier(random_state=42, n_jobs=-1)

# Treinando LGBMClassifier
LGBMClassifier.fit(X_train_boruta, np.ravel(y_train))

# Calculando as probabilidades de predição
y_pred_rf_prob = LGBMClassifier.predict_proba(X_test_boruta)[:,1]

# %%
# Plotando a curva ROC AUC
fig, ax = plt.subplots()

ax.figure.set_size_inches(10, 6)

ns_probs = [0 for _ in range(len(y_test))]

ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
rf_fpr, rf_tpr, _ = roc_curve(y_test, y_pred_rf_prob)

plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Sem Habilidade')
plt.plot(rf_fpr, rf_tpr, marker='.', label='LGBMClassifier')

plt.title("ROC Curve", fontsize=14)
plt.xlabel('Falso Positivo')
plt.ylabel('Verdadeiro Positivo')

plt.legend()

plt.show()

# %%
pickle.dump(LGBMClassifier, open('model/LGBMClassifier.pkl', 'wb'))

# %% [markdown]
# ## 9.3 Matriz de Confusão

# %% [markdown]
# Como podemos observar, na matriz de confusão(confusion matriz), o modelo **LGBMClassifier** é o que possui maior equilíbrio entre falsos positivos e falsos negativos, por isso escolhemos esse modelo.

# %%
# Selecionar as dimensões das subplots
n_rows = 3
n_cols = 3
threshold = 0.45
model = classifiers
qualifier=""

# Plotando matriz de confusão
fig, ax = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(15, 10))

for clf, ax, n in zip(classifiers, ax.flatten(), list(range(n_rows*n_cols))):
    clf_probs = clf.predict_proba(X_test_boruta)

    probs = pd.DataFrame(clf_probs[:, 1], columns=['prob_positivo'])

    y_pred = probs['prob_positivo'].apply(
        lambda x: 1 if x > threshold else 0)

    plt.subplot(n_rows, n_cols, n+1)
    cm = confusion_matrix(y_test, y_pred)

    ax = sns.heatmap(cm, annot=True, fmt='g', cmap='viridis',
                    square=True, annot_kws={"size": 14})

    plt.xlabel("ESTIMADO")
    plt.ylabel("REAL")
    ax.title.set_text(type(clf).__name__ + ' ' + str(qualifier))

plt.tight_layout()

plt.show()

# %% [markdown]
# # 9.4 Validação-Cruzada

# %% [markdown]
# Usamos a Validação-Cruzada(**Cross-Validation**) para tentar melhorar nosso modelo.

# %%
# Concatenando dados de teste e treino pelo método Boruta
X_all = pd.concat([X_train_boruta, X_test_boruta], axis=0)
y_all = pd.concat([y_train, y_test], axis=0)

# %%
LGBMClassifier = pickle.load(open('model/LGBMClassifier.pkl', 'rb'))

# %%
# Instanciando o StratifiedKFold para Cross-validation
cv = StratifiedKFold(n_splits=10)

# %%
# Calculando acurácia de precision
cv_scores = cross_val_score(LGBMClassifier, X_all, y_all, cv=cv, scoring='precision', n_jobs=1)
print("Average precision : %0.4f (+/- %0.4f)" % (cv_scores.mean(), cv_scores.std() * 2))
print()

# Calculando acurácia de recall
cv_scores1 = cross_val_score(LGBMClassifier, X_all, y_all, cv=cv, scoring='recall', n_jobs=1)
print("Average recall : %0.4f (+/- %0.4f)" % (cv_scores1.mean(), cv_scores1.std() * 2))
print()

# Calculando acurácia de f1-score
cv_score2 = cross_val_score(LGBMClassifier, X_all, y_all, cv=cv, scoring='f1', n_jobs=1)
print("Average f1-score : %0.4f (+/- %0.4f)" % (cv_score2.mean(), cv_score2.std() * 2))
print()

# Calculando acurácia de roc_auc
cv_score3 = cross_val_score(LGBMClassifier, X_all, y_all, cv=cv, scoring='roc_auc', n_jobs=1)
print("Average roc_auc : %0.4f (+/- %0.4f)" % (cv_score3.mean(), cv_score3.std() * 2))
print()
# Out:
# Average precision : 0.7398 (+/- 0.0209)
#
# Average recall : 0.6801 (+/- 0.0175)
#
# Average f1-score : 0.7086 (+/- 0.0134)
#
# Average roc_auc : 0.7886 (+/- 0.0133)

# %% [markdown]
# # 10 Hiperparâmetros

# %% [markdown]
# Através dos hiperparâmetros vamos encontrar o desvio padrão de cada acurácia e aplicar no modelo.

# %%
LGBMClassifier = pickle.load(open('model/LGBMClassifier.pkl', 'rb'))

# %%
# Configurar com hiperparâmetros especificados
space = {'max_depth': np.arange(2, 12, 2), 
         'learning_rate': np.linspace(0.001, 0.6, 15),
         'colsample_bytree': np.linspace(0.1, 1, 5),
         'subsample': np.linspace(0.25, 1, 15),
         'n_estimators': np.arange(10, 105, 15)}

# Preparar para treinar o RandomizedSearchCV
LGBM_ = RandomizedSearchCV(estimator=LGBMClassifier, param_distributions=space,
                                scoring='f1', n_iter=100, cv=5, verbose=2,
                                random_state=42, n_jobs=-1)

# %%
# Treinar os dados pelo RandomizedSearchCV
LGBM_.fit(X_train_boruta.values,y_train.values)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=LGBMClassifier(random_state=42), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'colsample_bytree': array([0.1  , 0.325, 0.55 , 0.775, 1.   ]),
#                                         'learning_rate': array([0.001     , 0.04378571, 0.08657143, 0.12935714, 0.17214286,
#        0.21492857, 0.25771429, 0.3005    , 0.34328571, 0.38607143,
#        0.42885714, 0.47164286, 0.51442857, 0.55721429, 0.6       ]),
#                                         'max_depth': array([ 2,  4,  6,  8, 10]),
#                                         'n_estimators': array([ 10,  25,  40,  55,  70,  85, 100]),
#                                         'subsample': array([0.25      , 0.30357143, 0.35714286, 0.41071429, 0.46428571,
#        0.51785714, 0.57142857, 0.625     , 0.67857143, 0.73214286,
#        0.78571429, 0.83928571, 0.89285714, 0.94642857, 1.        ])},
#                    random_state=42, scoring='f1', verbose=2)

# %%
# Calcular o melhor estimator para Modelo Final
LGBM_.best_estimator_
# Out:
# LGBMClassifier(learning_rate=0.5144285714285713, max_depth=2, n_estimators=25,
#                random_state=42, subsample=0.4642857142857143)

# %%
pickle.dump(LGBM_.best_estimator_, open('model/LGBM_.best_model.pkl', 'wb'))

# %% [markdown]
# ## 10.1 Modelo Final

# %% [markdown]
# Por fim, vamos aplicar o modelo final de acordo com os dados do hiperparâmetro com o objetivo de obter o melhor resultado junto à melhor e pior hipótese(desvio padrão).

# %%
lgbm_final_model = pickle.load(open('model/LGBM_.best_model.pkl', 'rb'))

# %%
# Calculando acurácia de precision
cv_scores = cross_val_score(lgbm_final_model, X_all, y_all, cv=cv, scoring='precision', n_jobs=1)
print("Average precision : %0.4f (+/- %0.4f)" % (cv_scores.mean(), cv_scores.std() * 2))
print()

# Calculando acurácia de recall
cv_scores1 = cross_val_score(lgbm_final_model, X_all, y_all, cv=cv, scoring='recall', n_jobs=1)
print("Average recall : %0.4f (+/- %0.4f)" % (cv_scores1.mean(), cv_scores1.std() * 2))
print()

# Calculando acurácia de f1-score
cv_score2 = cross_val_score(lgbm_final_model, X_all, y_all, cv=cv, scoring='f1', n_jobs=1)
print("Average f1-score : %0.4f (+/- %0.4f)" % (cv_score2.mean(), cv_score2.std() * 2))
print()

# Calculando acurácia de roc_auc
cv_score3 = cross_val_score(lgbm_final_model, X_all, y_all, cv=cv, scoring='roc_auc', n_jobs=1)
print("Average roc_auc : %0.4f (+/- %0.4f)" % (cv_score3.mean(), cv_score3.std() * 2))
print()
# Out:
# Average precision : 0.7391 (+/- 0.0176)
#
# Average recall : 0.6833 (+/- 0.0168)
#
# Average f1-score : 0.7101 (+/- 0.0137)
#
# Average roc_auc : 0.7887 (+/- 0.0136)

# %% [markdown]
# # 11 Performance de Negócio

# %% [markdown]
# Após todo esse processo, podemos ter um resultado se a empresa vai ter lucro ou não. Atualmente, ela possui uma acurácia máxima de 65% nos seus diagnósticos médicos. A cada 5% adicional, acima de 50%, é cobrado R$500,00 a mais dos clientes.
#
#
#
# |Acurácia de Diagnóstico | Preço       | Regra              | Exemplo                      |
# :------------------------ | :----------- | :------------------ | :-----------------------------|
# | 50% para baixo         | R\$0\,00       | Nenhum             | Acurácia = 45% \-> R\$0.00      |
# | Acima de 50%           | R\$500\,00 mínimo | +R\$500\.00 a cada 5% | Acurácia = 60% \-> R\$1.500 |
#
#
#
#
# Nosso modelo conseguiu atingir uma acurácia entre **72,15%** e **75,67%** com a base de dados dos 70000 clientes da empresa. Então, na melhor das hipóteses, se pelo método normal todos que possuem ou não DCV conseguissem uma acurácia médica de 65%, a empresa faturaria **R\$105 milhões** e pela nossa precisão atingida, na melhor das hipóteses(75,67%) a empresa faturaria **R\$179\.69 milhões**, uma diferença de **R\$74\.69 milhões**(lucro bastante positivo) e na pior das hipóteses(72,15%) a empresa faturaria **R\$155\.05 milhões**, uma diferença de **R\$50\.05 milhões**(lucro bastante positivo também).
#
# |                         | Melhor cenário     | Pior cenário        |
# :------------------------ | :------------------| :------------------ |
# | Atualmente              | R\$105.000.000\,00 | R\$35.000.000\,00   |
# | Após nosso modelo       | R\$179.690.000\,00 | R\$155.005.000\,00  |
# | Diferença               | R\$74.690.000\,00 | R\$50.005.000\,00    |
